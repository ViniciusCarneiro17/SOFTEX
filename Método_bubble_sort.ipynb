# %% [markdown]
# <a href="https://colab.research.google.com/github/ViniciusCarneiro17/SOFTEX/blob/main/M%C3%A9todo_bubble_sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L = [98,97,96,95,94,93,92,91,90,24]
print("L: ", L)
# Out:
# L:  [98, 97, 96, 95, 94, 93, 92, 91, 90, 24]

# %%
for i in range(9):

  if (L[0] > L[1]):
    x = L[0]
    y = L[1]
    L[0] = y
    L[1] = x
    print("L:",L)
  else:
    print("L:", L)

  if (L[1] > L[2]):
    x = L[1]
    y = L[2]
    L[1] = y
    L[2] = x
    print("L:", L)
  else:
    print("L:", L)

  if (L[2] > L[3]):
    x = L[2]
    y = L[3]
    L[2] = y
    L[3] = x
    print("L:", L)
  else:
    print("L:", L)

  if (L[3] > L[4]):
    x = L[3]
    y = L[4]
    L[3] = y
    L[4] = x
    print("L:", L)
  else:
    print("L:", L)

  if (L[4] > L[5]):
    x = L[4]
    y = L[5]
    L[4] = y
    L[5] = x
    print("L:", L)
  else:
    print("L:", L)

  if (L[5] > L[6]):
    x = L[5]
    y = L[6]
    L[5] = y
    L[6] = x
    print("L:", L)
  else:
    print("L:", L)

  if (L[6] > L[7]):
    x = L[6]
    y = L[7]
    L[6] = y
    L[7] = x
    print("L:", L)
  else:
    print("L:", L)

  if (L[7] > L[8]):
   x = L[7]
   y = L[8]
   L[7] = y
   L[8] = x
   print("L:", L)
  else:
   print("L:", L)

  if (L[8] > L[9]):
   x = L[8]
   y = L[9]
   L[8] = y
   L[9] = x
   print("L:", L)
  else:
   print("L:", L)
# Out:
# L: [97, 98, 96, 95, 94, 93, 92, 91, 90, 24]
# L: [97, 96, 98, 95, 94, 93, 92, 91, 90, 24]
# L: [97, 96, 95, 98, 94, 93, 92, 91, 90, 24]
# L: [97, 96, 95, 94, 98, 93, 92, 91, 90, 24]
# L: [97, 96, 95, 94, 93, 98, 92, 91, 90, 24]
# L: [97, 96, 95, 94, 93, 92, 98, 91, 90, 24]
# L: [97, 96, 95, 94, 93, 92, 91, 98, 90, 24]
# L: [97, 96, 95, 94, 93, 92, 91, 90, 98, 24]
# L: [97, 96, 95, 94, 93, 92, 91, 90, 24, 98]
# L: [96, 97, 95, 94, 93, 92, 91, 90, 24, 98]
# L: [96, 95, 97, 94, 93, 92, 91, 90, 24, 98]
# L: [96, 95, 94, 97, 93, 92, 91, 90, 24, 98]
# L: [96, 95, 94, 93, 97, 92, 91, 90, 24, 98]
# L: [96, 95, 94, 93, 92, 97, 91, 90, 24, 98]
# L: [96, 95, 94, 93, 92, 91, 97, 90, 24, 98]
# L: [96, 95, 94, 93, 92, 91, 90, 97, 24, 98]
# L: [96, 95, 94, 93, 92, 91, 90, 24, 97, 98]
# L: [96, 95, 94, 93, 92, 91, 90, 24, 97, 98]
# L: [95, 96, 94, 93, 92, 91, 90, 24, 97, 98]
# L: [95, 94, 96, 93, 92, 91, 90, 24, 97, 98]
# L: [95, 94, 93, 96, 92, 91, 90, 24, 97, 98]
# ...
